# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
end1 = dt.date(2022, 11, 15) 
start1 = dt.date(2022, 1, 1)

nifty_fut = yf.download("^NSEI", start = start1, end = end1, parse_dates=True, index_col=0)
bank_nif_fut = yf.download("^NSEBANK", start = start1, end = end1, parse_dates=True, index_col=0)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
del nifty_fut["Open"]
del nifty_fut["Close"]
del nifty_fut["Adj Close"]
del nifty_fut["Volume"]
df1 = nifty_fut
df1["Difference"] = (df1["High"] - df1["Low"])

# %%
del bank_nif_fut["Open"]
del bank_nif_fut["Close"]
del bank_nif_fut["Adj Close"]
del bank_nif_fut["Volume"]
df2 = bank_nif_fut
df2["Diff"] = (df2["High"] - df2["Low"])

# %%
plt.plot(df1["Difference"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
avg_nif=df1["Difference"].mean()
std_nif= df1["Difference"].std()
maximum_nif = df1["Difference"].max()
min_nif = df1["Difference"].min()

# %%
avg_nif
# Out:
# 212.45307480286215

# %%
std_nif
# Out:
# 94.3237359841618

# %%
maximum_nif
# Out:
# 601.55078125

# %%
min_nif
# Out:
# 70.150390625

# %%
avg_bank_nif=df2["Diff"].mean()
std_bank_nif=df2["Diff"].std()
maximum_bank_nif = df2["Diff"].max()
min_bank_nif = df2["Diff"].min()

# %%
avg_bank_nif
# Out:
# 620.2262521904206

# %%
std_bank_nif
# Out:
# 276.1859803665633

# %%
maximum_bank_nif
# Out:
# 1717.796875

# %%
min_bank_nif
# Out:
# 210.3515625

# %%
ax = sns.distplot(df1["Difference"]).set(title='NIFTY50')
plt.show()

# %%
ax = sns.distplot(df2["Diff"]).set(title='BANKNIFTY')
plt.show()
